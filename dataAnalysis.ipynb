# %%
import pandas as pd
df1=pd.read_csv(r"d:\Pendrive_Backup\titanic_dataset.csv")
dfC=df1
dfC
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfC.shape
dfC.info()

dfC.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
dfC.shape
# Out:
# (891, 12)

# %%
dfC.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dfC.duplicated().sum()
# Out:
# np.int64(0)

# %%
dfC.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dfC.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dfC["Survived"].dtype
# Out:
# dtype('int64')

# %%
dfC.shape[0]
# Out:
# 891

# %%
dfC["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Q3: Survival percentage
dfC["Survived"].value_counts(normalize=True)*100
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
# Q4: Survival rate by Pclass

dfC.groupby("Pclass")["Survived"].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
# Q5: Average age
round(dfC["Age"].mean(),2)
# Out:
# np.float64(29.7)

# %%
dfC["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Q7: Survival by Gender

dfC.groupby("Gender")["Survived"].mean()*100
# Out:
# Gender
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
# Q8: Survival by Child vs Adult 

dfC['Child'] = dfC['Age'] < 18 
print("\nQ8: Survival rate (Child vs Adult)")
print(dfC.groupby('Child')['Survived'].mean() * 100)


dfC["Child"]
dfC.columns
# Out:
# Q8: Survival rate (Child vs Adult)
# Child
# False    36.118252
# True     53.982301
# Name: Survived, dtype: float64
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Child'],
#       dtype='object')

# %%
#continuation.......

dfC["Adult"]=dfC["Age"]>18


dfC.groupby(["Adult","Child"])["Survived"]


dfC.groupby("Gender")["PassengerId"]

# %%
dfC.groupby(['Pclass', 'Gender'])['Survived'].mean() * 100
# Out:
# Pclass  Gender
# 1       female    96.808511
#         male      36.885246
# 2       female    92.105263
#         male      15.740741
# 3       female    50.000000
#         male      13.544669
# Name: Survived, dtype: float64

# %%
dfC.groupby(['Pclass', 'Gender', 'Embarked'])['Survived'].mean() * 100
# Out:
# Pclass  Gender  Embarked
# 1       female  C            97.674419
#                 Q           100.000000
#                 S            95.833333
#         male    C            40.476190
#                 Q             0.000000
#                 S            35.443038
# 2       female  C           100.000000
#                 Q           100.000000
#                 S            91.044776
#         male    C            20.000000
#                 Q             0.000000
#                 S            15.463918
# 3       female  C            65.217391
#                 Q            72.727273
#                 S            37.500000
#         male    C            23.255814
#                 Q             7.692308
#                 S            12.830189
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import io



# Create histogram for Age distribution
plt.figure(figsize=(8, 6))
sns.histplot(dfC['Age'].dropna(), bins=40, kde=True, color='blue')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Calculate average age for survivors and non-survivors
avg_age = dfC.groupby('Survived')['Age'].mean()
print("Average age by survival status:")
print(f"Survivors: {avg_age[1]:.2f} years")
print(f"Non-survivors: {avg_age[0]:.2f} years")
# Out:
# Average age by survival status:
# Survivors: 28.34 years
# Non-survivors: 30.63 years

# %% [markdown]
# # Explore the relationship between 'Fare' and 'Survived' by grouping data and calculating average fare for survivors and non-survivors, then create a box plot

# %%
# Calculate average fare for survivors and non-survivors
avg_fare = dfC.groupby('Survived')['Fare'].mean()
print("Average fare by survival status:")
print(f"Survivors: {avg_fare[1]:.2f}")
print(f"Non-survivors: {avg_fare[0]:.2f}")

# Create box plot for Fare by Survived
plt.figure(figsize=(8, 6))
sns.boxplot(x='Survived', y='Fare', data=dfC, palette='viridis')
plt.title('Fare Distribution by Survival Status')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Fare')
plt.show()
# Out:
# Average fare by survival status:
# Survivors: 48.40
# Non-survivors: 22.12
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9320\2297921132.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Survived', y='Fare', data=dfC, palette='viridis')

# %% [markdown]
# # Investigate gender-based survival by creating a crosstab of 'Gender' and 'Survived', and compute the survival percentage for males and females.

# %%
# Calculate IQR for Fare
Q1 = dfC['Fare'].quantile(0.25)
Q3 = dfC['Fare'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 3 * IQR

# Identify outliers
outliers = dfC[dfC['Fare'] > upper_bound][['PassengerId', 'Fare']]
print("Passengers with Fare outliers (Fare > Q3 + 3*IQR):")
print(outliers)
# Out:
# Passengers with Fare outliers (Fare > Q3 + 3*IQR):
#      PassengerId      Fare
# 27            28  263.0000
# 31            32  146.5208
# 88            89  263.0000
# 118          119  247.5208
# 195          196  146.5208
# 215          216  113.2750
# 258          259  512.3292
# 268          269  153.4625
# 269          270  135.6333
# 297          298  151.5500
# 299          300  247.5208
# 305          306  151.5500
# 306          307  110.8833
# 307          308  108.9000
# 311          312  262.3750
# 318          319  164.8667
# 319          320  134.5000
# 325          326  135.6333
# 332          333  153.4625
# 334          335  133.6500
# 337          338  134.5000
# 341          342  263.0000
# 373          374  135.6333
# 377          378  211.5000
# 380          381  227.5250
# 390          391  120.0000
# 393          394  113.2750
# 435          436  120.0000
# 438          439  263.0000
# 498          499  151.5500
# 505          506  108.9000
# ...

# %% [markdown]
# # Analyze family size by creating a new column 'FamilySize' = SibSp + Parch + 1, then plot the survival rate against family size.

# %%
# Create FamilySize column
dfC['FamilySize'] = dfC['SibSp'] + dfC['Parch'] + 1

# Calculate survival rate by FamilySize
survival_rate = dfC.groupby('FamilySize')['Survived'].mean() * 100

# Print survival rate
print("Survival rate by FamilySize (%):")
print(survival_rate)

# Create bar plot for survival rate by FamilySize
plt.figure(figsize=(8, 6))
sns.barplot(x=survival_rate.index, y=survival_rate.values, palette='viridis')
plt.title('Survival Rate by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate (%)')
plt.show()
# Out:
# Survival rate by FamilySize (%):
# FamilySize
# 1     30.353818
# 2     55.279503
# 3     57.843137
# 4     72.413793
# 5     20.000000
# 6     13.636364
# 7     33.333333
# 8      0.000000
# 11     0.000000
# Name: Survived, dtype: float64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9320\3798156734.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate.index, y=survival_rate.values, palette='viridis')

# %% [markdown]
# # Examine embarkation points by counting passengers from each 'Embarked' location, and create a pie chart showing the proportion, along with survival rates per port

# %%
# Count passengers by Embarked
embarked_counts = dfC['Embarked'].value_counts()
print("Passenger count by Embarked:")
print(embarked_counts)

# Calculate survival rate by Embarked
survival_rate = dfC.groupby('Embarked')['Survived'].mean() * 100
print("\nSurvival rate by Embarked (%):")
print(survival_rate)

# Create pie chart for Embarked proportions
plt.figure(figsize=(8, 6))
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', colors=sns.color_palette('viridis'))
plt.title('Proportion of Passengers by Embarkation Point')
plt.show()
# Out:
# Passenger count by Embarked:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
#
# Survival rate by Embarked (%):
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %% [markdown]
# # Correlate numerical features by computing a correlation matrix for 'Age', 'Fare', 'SibSp', 'Parch', 'Pclass', and 'Survived', and visualize it as a heatmap.

# %%
# Select numerical columns
numerical_cols = ['Age', 'Fare', 'SibSp', 'Parch', 'Pclass', 'Survived']
correlation_matrix = dfC[numerical_cols].corr()

# Print correlation matrix
print("Correlation matrix for numerical features:")
print(correlation_matrix)

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Features')
plt.show()
# Out:
# Correlation matrix for numerical features:
#                Age      Fare     SibSp     Parch    Pclass  Survived
# Age       1.000000  0.096067 -0.308247 -0.189119 -0.369226 -0.077221
# Fare      0.096067  1.000000  0.159651  0.216225 -0.549500  0.257307
# SibSp    -0.308247  0.159651  1.000000  0.414838  0.083081 -0.035322
# Parch    -0.189119  0.216225  0.414838  1.000000  0.018443  0.081629
# Pclass   -0.369226 -0.549500  0.083081  0.018443  1.000000 -0.338481
# Survived -0.077221  0.257307 -0.035322  0.081629 -0.338481  1.000000

# %% [markdown]
# # Handle missing 'Age' values by imputing them with the median age per 'Pclass' and 'Gender', then compare the age distribution before and after imputation.

# %%
# Plot age distribution before imputation
plt.figure(figsize=(8, 6))
sns.histplot(dfC['Age'].dropna(), bins=30, kde=True, color='blue', label='Before Imputation')
plt.title('Age Distribution Before and After Imputation')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Impute missing Age values with median per Pclass and Gender
dfC['Age_imputed'] = dfC.groupby(['Pclass', 'Gender'])['Age'].transform(lambda x: x.fillna(x.median()))

# Plot age distribution after imputation
sns.histplot(dfC['Age_imputed'], bins=30, kde=True, color='orange', label='After Imputation', alpha=0.5)
plt.legend()
plt.show()

# Compare summary statistics
print("Age statistics before imputation:")
print(dfC['Age'].describe())
print("\nAge statistics after imputation:")
print(dfC['Age_imputed'].describe())
# Out:
# Age statistics before imputation:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
#
# Age statistics after imputation:
# count    891.000000
# mean      29.112424
# std       13.304424
# min        0.420000
# 25%       21.500000
# 50%       26.000000
# 75%       36.000000
# max       80.000000
# Name: Age_imputed, dtype: float64

# %% [markdown]
# # Explore title extraction from 'Name' column (e.g., Mr., Mrs.), create a new 'Title' column, and analyze survival rates by title

# %%
# Extract Title from Name
dfC['Title'] = dfC['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Calculate survival rate by Title
survival_rate = dfC.groupby('Title')['Survived'].mean() * 100
print("Survival rate by Title (%):")
print(survival_rate.sort_values(ascending=False))
# Out:
# Survival rate by Title (%):
# Title
# Countess    100.000000
# Ms          100.000000
# Lady        100.000000
# Mme         100.000000
# Mlle        100.000000
# Sir         100.000000
# Mrs          79.200000
# Miss         69.780220
# Master       57.500000
# Major        50.000000
# Col          50.000000
# Dr           42.857143
# Mr           15.667311
# Capt          0.000000
# Don           0.000000
# Jonkheer      0.000000
# Rev           0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# # Investigate the impact of cabin deck (first letter of 'Cabin') on survival by extracting 'Deck', handling missing cabins, and plotting survival rates per deck

# %%
# Extract Deck from Cabin (first letter)
dfC['Deck'] = dfC['Cabin'].str[0]

# Handle missing cabins by assigning 'Unknown'
dfC['Deck'] = dfC['Deck'].fillna('Unknown')

# Calculate survival rate by Deck
survival_rate = dfC.groupby('Deck')['Survived'].mean() * 100
print("Survival rate by Deck (%):")
print(survival_rate)

# Create bar plot for survival rate by Deck
plt.figure(figsize=(8, 6))
sns.barplot(x=survival_rate.index, y=survival_rate.values, palette='viridis')
plt.title('Survival Rate by Deck')
plt.xlabel('Deck')
plt.ylabel('Survival Rate (%)')
plt.show()
# Out:
# Survival rate by Deck (%):
# Deck
# A          46.666667
# B          74.468085
# C          59.322034
# D          75.757576
# E          75.000000
# F          61.538462
# G          50.000000
# T           0.000000
# Unknown    29.985444
# Name: Survived, dtype: float64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9320\4173085758.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate.index, y=survival_rate.values, palette='viridis')

# %% [markdown]
# # Perform a multivariate analysis by creating a pairplot for 'Age', 'Fare', 'Pclass', and 'Survived' colored by 'Gender' to identify patterns.

# %%
# Select columns for pairplot
pairplot_cols = ['Age', 'Fare', 'Pclass', 'Survived']

# Create pairplot
sns.pairplot(dfC[pairplot_cols].dropna(), hue='Survived', palette='viridis', diag_kind='kde')
plt.suptitle('Pairplot of Age, Fare, Pclass, and Survived', y=1.02)
plt.show()
